# %% [markdown]
# # Ex -

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np 
import pandas as pd
data = pd.read_csv('temp_datalab_records_social_facebook.csv')
# Out:
# /Users/tammy/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
#data.entity_id.isnull().count()
#data = data.drop(['entity_id'], axis=1)
#data.cusip.isnull().count()
#data['isin'].isnull().count()
#data = data.drop(['cusip','isin'], axis=1)
#data = data.drop(['has_added_app'], axis=1)
data.head()
# Out:
#    dataset_id                    time              username  checkins  \
# 0       53088  2015-01-01 05:00:00+00            SodaStream         0
# 1       52642  2015-01-01 05:00:00+00              ANSYSInc       148
# 2       53656  2015-01-01 05:00:00+00         MyAquaAmerica         0
# 3       53033  2015-01-01 05:00:00+00              Qualcomm       173
# 4       52783  2015-01-01 05:00:00+00  eaglepharmaceuticals         0
#
#    were_here_count    likes  talking_about_count       facebook_id date_added  \
# 0                0   761533                  587       54885616308        NaN
# 1                0    43442                 1305   160242297413411        NaN
# 2                0     5591                  297   591693544195818        NaN
# 3                0  1232521                 2685      108472637291        NaN
# 4                0       18                    0  1428265940729350        NaN
#
#                     date_updated  Year
# 0  2017-02-14 03:35:13.236826+00  2015
# 1   2017-02-14 01:55:52.78506+00  2015
# 2  2017-02-14 08:13:51.267343+00  2015
# 3  2017-02-14 03:24:04.363035+00  2015
# 4  2017-02-14 02:22:10.193588+00  2015

# %% [markdown]
# ### Step 4. What is the total number of persons injured in the dataset (up to December 31, 2018?)

# %%
#data['Year']=pd.DatetimeIndex(data.time).year
#data.groupby('Year').checkins.max()
#data.loc[data.Year == 2017].sort_values('talking_about_count', ascending = False)
'''
Year
2015     2667097
2016     3335667
2017    16467964
2018    17290550
'''
#data.groupby(['dataset_id','Year']).max().sort_values('checkins',ascending = False).head(30)
data.loc[data['dataset_id']==911420].groupby('Year').sum().sort_values('were_here_count',ascending = False).head(30)
# Out:
#       dataset_id    checkins  were_here_count       likes  \
# Year
# 2017   316262740  5375421548       4987961733  6193824665
# 2018   140358680  2591069526       2595514515  2756896474
#
#       talking_about_count    facebook_id  month
# Year
# 2017             53643586  3845416087127   2364
# 2018             18336883  1706611174114    489

# %% [markdown]
# ### Step 5. What proportion of collisions in 2016 resulted in injury or death of a cyclist?

# %%
#data['month']=pd.DatetimeIndex(data.time).month
#data.loc[data.Year == 2018].groupby('month').checkins.max()
#data.loc[data.Year == 2017].groupby(['username','month']).checkins.max().sort_values(ascending = False).head(24)

data_BuschGardens=data.loc[data.dataset_id==55545]
data_BuschGardens = data_BuschGardens.set_index(pd.to_datetime(data_BuschGardens['time']))
#[['talking_about_count','checkins']]
#checkin_aggMonth=data_BuschGardens.resample('M').max()[['talking_about_count','checkins','likes']]
checkin_month = checkin_aggMonth.diff()
checkin_month
# Out:
#             talking_about_count  checkins    likes
# time
# 2015-07-31                  NaN       NaN      NaN
# 2015-08-31               1362.0   34931.0   6111.0
# 2015-09-30               -378.0   24017.0   4010.0
# 2015-10-31              -1707.0   66421.0  35602.0
# 2015-11-30               -600.0   30270.0   3697.0
# 2015-12-31               6012.0   52519.0   4450.0
# 2016-01-31               7269.0   35603.0   3254.0
# 2016-02-29             -11529.0   30984.0   2571.0
# 2016-03-31               4274.0   49397.0   4088.0
# 2016-04-30              10807.0   45824.0   5711.0
# 2016-05-31              65074.0   39331.0  13990.0
# 2016-06-30             -67560.0   35735.0   4242.0
# 2016-07-31               3766.0  136941.0   8600.0
# 2016-08-31              -9794.0   32575.0   3156.0
# 2016-09-30              -9679.0   21708.0   1574.0
# 2016-10-31               2766.0   34537.0   2099.0
# 2016-11-30               4080.0   32033.0   1891.0
# 2016-12-31               6259.0   51564.0   3032.0
# 2017-01-31              -1853.0   30680.0   1742.0
# 2017-02-28              -2346.0   29360.0   1866.0
# 2017-03-31              -2885.0   48962.0   6682.0
# 2017-04-30                271.0   50553.0   1207.0
# 2017-05-31              -3873.0   36988.0    802.0
# 2017-06-30                372.0   33092.0   2403.0
# 2017-07-31               4533.0   49371.0   6380.0
# 2017-08-31               -982.0   27618.0   2616.0
# 2017-09-30               9183.0   19829.0   5557.0
# 2017-10-31              -2293.0   33027.0   5292.0
# 2017-11-30              -2106.0  109295.0   4190.0
# 2017-12-31               7877.0   35805.0   3361.0
# 2018-01-31               3456.0   26181.0   1948.0
# 2018-02-28             -18877.0   25507.0   1603.0
# 2018-03-31              13192.0   39791.0   4070.0
# 2018-04-30              11383.0   39927.0   5054.0
# 2018-05-31              -8429.0   22604.0   6576.0
# 2018-06-30              -3291.0   38133.0   5738.0
# 2018-07-31             -10962.0   31978.0   2352.0

# %% [markdown]
# ### Step 6. What proportion of all collisions in 2016 occured in Brooklyn? Only consider entries with a non-null value for BOROUGH.

# %%
data_DisneyLand=data.loc[data.dataset_id==911420]
data_DisneyLand = data_DisneyLand.set_index(pd.to_datetime(data_DisneyLand['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_DisneyLand.resample('M').max()[['talking_about_count','were_here_count','checkins']]
checkin_month = checkin_aggMonth.diff()
#checkin_day=data_DisneyLand[['talking_about_count','checkins']]
#checkin_dayD = checkin_day.diff()
#checkin_month
print (checkin_aggMonth.corr())
print (checkin_month.corr())
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
#Disneyland
# Out:
#                      talking_about_count  were_here_count  checkins
# talking_about_count             1.000000        -0.278888 -0.271187
# were_here_count                -0.278888         1.000000  0.999922
# checkins                       -0.271187         0.999922  1.000000
#                      talking_about_count  were_here_count  checkins
# talking_about_count             1.000000         0.071718  0.068033
# were_here_count                 0.071718         1.000000  0.998290
# checkins                        0.068033         0.998290  1.000000

# %% [markdown]
# ### Step 7. Obtain the number of vehicles involved in each collision in 2016. Group the collisions by zip code and compute the sum of all vehicles involved in collisions in each zip code, then report the maximum of these values.

# %%
data_WaltDisneyWorld=data.loc[data.dataset_id==911419]
data_WaltDisneyWorld = data_WaltDisneyWorld.set_index(pd.to_datetime(data_WaltDisneyWorld['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_WaltDisneyWorld.resample('M').max()[['talking_about_count','checkins']]
checkin_month = checkin_aggMonth.diff()
#checkin_month
print (checkin_aggMonth.corr())
print (checkin_month.corr())
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
#WaltDisneyWorld
# Out:
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.522151
# checkins                       -0.522151  1.000000
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.047781
# checkins                       -0.047781  1.000000

# %% [markdown]
# ### Step 8. Do winter driving conditions lead to more multi-car collisions? Compute the rate of multi car collisions as the proportion of the number of collisions involving 3 or more cars to the total number of collisions for each month of 2017. Calculate the chi-square test statistic for testing whether a collision is more likely to involve 3 or more cars in January than in May.

# %%
data_DisneylandParisfr=data.loc[data.dataset_id==911422]
data_DisneylandParisfr = data_DisneylandParisfr.set_index(pd.to_datetime(data_DisneylandParisfr['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_DisneylandParisfr.resample('M').max()[['talking_about_count','checkins']]
checkin_month = checkin_aggMonth.diff()
print (checkin_aggMonth.corr())
print (checkin_month.corr())
#checkin_month
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
#DisneylandParisfr
# Out:
#                      talking_about_count  checkins
# talking_about_count              1.00000  -0.67654
# checkins                        -0.67654   1.00000
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.079603
# checkins                       -0.079603  1.000000

# %% [markdown]
# ### Step 9.

# %%
data_empire=data.loc[data.dataset_id==910583]
data_empire = data_empire.set_index(pd.to_datetime(data_empire['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_empire.resample('M').max()[['talking_about_count','checkins']]
checkin_month = checkin_aggMonth.diff()
#checkin_month
print (checkin_aggMonth.corr())
print (checkin_month.corr())
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
#empirestatebuilding
# Out:
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.599992
# checkins                       -0.599992  1.000000
#                      talking_about_count  checkins
# talking_about_count             1.000000  0.025005
# checkins                        0.025005  1.000000

# %% [markdown]
# ### Step 10. For each borough, compute the number of accidents per capita involving alcohol in 2017. Report the highest rate among the 5 boroughs. Use populations as given by https://en.wikipedia.org/wiki/Demographics_of_New_York_City.

# %%
data_KnottsBerryFarm=data.loc[data.dataset_id==55539]
data_KnottsBerryFarm = data_KnottsBerryFarm.set_index(pd.to_datetime(data_KnottsBerryFarm['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_KnottsBerryFarm.resample('M').max()[['talking_about_count','checkins']]
checkin_month = checkin_aggMonth.diff()
#checkin_month
print (checkin_aggMonth.corr())
print (checkin_month.corr())
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
#KnottsBerryFarm
# Out:
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.198929
# checkins                       -0.198929  1.000000
#                      talking_about_count  checkins
# talking_about_count             1.000000  0.126662
# checkins                        0.126662  1.000000

# %% [markdown]
# ### Step 11.

# %%
data_SeaWorld=data.loc[data.dataset_id==55546]
data_SeaWorld = data_SeaWorld.set_index(pd.to_datetime(data_SeaWorld['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_SeaWorld.resample('M').max()[['talking_about_count','checkins']]
checkin_month = checkin_aggMonth.diff()
#checkin_month
print (checkin_aggMonth.corr())
print (checkin_month.corr())
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
#SeaWorld
# Out:
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.045554
# checkins                       -0.045554  1.000000
#                      talking_about_count  checkins
# talking_about_count             1.000000 -0.398537
# checkins                       -0.398537  1.000000

# %% [markdown]
# ### Step 12.

# %%
data_BuschGardens=data.loc[data.dataset_id==55545]
data_BuschGardens = data_BuschGardens.set_index(pd.to_datetime(data_BuschGardens['time']))
#[['talking_about_count','checkins']]
checkin_aggMonth=data_BuschGardens.resample('M').max()[['talking_about_count','checkins']]
checkin_month = checkin_aggMonth.diff()
#checkin_month
print (checkin_aggMonth.corr())
print (checkin_month.corr())
print (pd.rolling_corr(checkin_month.iloc[:,0],checkin_month.iloc[:,1],2,pairwise=True))
import matplotlib.pyplot as plt
# %matplotlib inline  
#plt.plot(checkin_month.index,checkin_month[:], 'yo', checkin_month.index, fit_fn(checkin_month.index), '--k')
checkin_month.plot()
# Out:
#                      talking_about_count  checkins
# talking_about_count             1.000000  0.110898
# checkins                        0.110898  1.000000
#                      talking_about_count  checkins
# talking_about_count              1.00000   0.09325
# checkins                         0.09325   1.00000
# time
# 2015-07-31    NaN
# 2015-08-31    NaN
# 2015-09-30    1.0
# 2015-10-31   -1.0
# 2015-11-30   -1.0
# 2015-12-31    1.0
# 2016-01-31   -1.0
# 2016-02-29    1.0
# 2016-03-31    1.0
# 2016-04-30   -1.0
# 2016-05-31   -1.0
# 2016-06-30    1.0
# 2016-07-31    1.0
# 2016-08-31    1.0
# 2016-09-30   -1.0
# 2016-10-31    1.0
# 2016-11-30   -1.0
# 2016-12-31    1.0
# 2017-01-31    1.0
# 2017-02-28    1.0
# 2017-03-31   -1.0
# 2017-04-30    1.0
# 2017-05-31    1.0
# 2017-06-30   -1.0
# 2017-07-31    1.0
# 2017-08-31    1.0
# 2017-09-30   -1.0
# 2017-10-31   -1.0
# 2017-11-30    1.0
# 2017-12-31   -1.0
# 2018-01-31    1.0
# 2018-02-28    1.0
# 2018-03-31    1.0
# 2018-04-30   -1.0
# 2018-05-31    1.0
# 2018-06-30    1.0
# 2018-07-31    1.0
# Freq: M, dtype: float64
# /Users/tammy/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: pd.rolling_corr is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=2).corr(other=<Series>,pairwise=True)
#   if __name__ == '__main__':

# %%
checkin_month['pre_talk']=checkin_aggMonth.talking_about_count.shift(1)
checkin_month['pre_talk_2']=checkin_aggMonth.talking_about_count.shift(2)
checkin_month['pre_talk_3']=checkin_aggMonth.talking_about_count.shift(3)
checkin_month['sum_pre']=checkin_month['pre_talk_2']+checkin_month['pre_talk_3']

# %%
checkin_month
# Out:
#             talking_about_count  checkins  pre_talk  pre_talk_2   sum_pre  \
# time
# 2015-07-31                  NaN       NaN       NaN         NaN       NaN
# 2015-08-31               1362.0   34931.0   15612.0         NaN       NaN
# 2015-09-30               -378.0   24017.0   16974.0     15612.0       NaN
# 2015-10-31              -1707.0   66421.0   16596.0     16974.0   32586.0
# 2015-11-30               -600.0   30270.0   14889.0     16596.0   33570.0
# 2015-12-31               6012.0   52519.0   14289.0     14889.0   31485.0
# 2016-01-31               7269.0   35603.0   20301.0     14289.0   29178.0
# 2016-02-29             -11529.0   30984.0   27570.0     20301.0   34590.0
# 2016-03-31               4274.0   49397.0   16041.0     27570.0   47871.0
# 2016-04-30              10807.0   45824.0   20315.0     16041.0   43611.0
# 2016-05-31              65074.0   39331.0   31122.0     20315.0   36356.0
# 2016-06-30             -67560.0   35735.0   96196.0     31122.0   51437.0
# 2016-07-31               3766.0  136941.0   28636.0     96196.0  127318.0
# 2016-08-31              -9794.0   32575.0   32402.0     28636.0  124832.0
# 2016-09-30              -9679.0   21708.0   22608.0     32402.0   61038.0
# 2016-10-31               2766.0   34537.0   12929.0     22608.0   55010.0
# 2016-11-30               4080.0   32033.0   15695.0     12929.0   35537.0
# 2016-12-31               6259.0   51564.0   19775.0     15695.0   28624.0
# 2017-01-31              -1853.0   30680.0   26034.0     19775.0   35470.0
# 2017-02-28              -2346.0   29360.0   24181.0     26034.0   45809.0
# 2017-03-31              -2885.0   48962.0   21835.0     24181.0   50215.0
# 2017-04-30                271.0   50553.0   18950.0     21835.0   46016.0
# 2017-05-31              -3873.0   36988.0   19221.0     18950.0   40785.0
# 2017-06-30                372.0   33092.0   15348.0     19221.0   38171.0
# 2017-07-31               4533.0   49371.0   15720.0     15348.0   34569.0
# 2017-08-31               -982.0   27618.0   20253.0     15720.0   31068.0
# 2017-09-30               9183.0   19829.0   19271.0     20253.0   35973.0
# 2017-10-31              -2293.0   33027.0   28454.0     19271.0   39524.0
# 2017-11-30              -2106.0  109295.0   26161.0     28454.0   47725.0
# 2017-12-31               7877.0   35805.0   24055.0     26161.0   54615.0
# 2018-01-31               3456.0   26181.0   31932.0     24055.0   50216.0
# 2018-02-28             -18877.0   25507.0   35388.0     31932.0   55987.0
# 2018-03-31              13192.0   39791.0   16511.0     35388.0   67320.0
# 2018-04-30              11383.0   39927.0   29703.0     16511.0   51899.0
# 2018-05-31              -8429.0   22604.0   41086.0     29703.0   46214.0
# 2018-06-30              -3291.0   38133.0   32657.0     41086.0   70789.0
# 2018-07-31             -10962.0   31978.0   29366.0     32657.0   73743.0
#
#             pre_talk_3
# time
# 2015-07-31         NaN
# 2015-08-31         NaN
# 2015-09-30         NaN
# 2015-10-31     15612.0
# 2015-11-30     16974.0
# 2015-12-31     16596.0
# 2016-01-31     14889.0
# 2016-02-29     14289.0
# 2016-03-31     20301.0
# 2016-04-30     27570.0
# 2016-05-31     16041.0
# 2016-06-30     20315.0
# 2016-07-31     31122.0
# 2016-08-31     96196.0
# 2016-09-30     28636.0
# 2016-10-31     32402.0
# 2016-11-30     22608.0
# 2016-12-31     12929.0
# 2017-01-31     15695.0
# 2017-02-28     19775.0
# 2017-03-31     26034.0
# 2017-04-30     24181.0
# 2017-05-31     21835.0
# 2017-06-30     18950.0
# 2017-07-31     19221.0
# 2017-08-31     15348.0
# 2017-09-30     15720.0
# 2017-10-31     20253.0
# 2017-11-30     19271.0
# 2017-12-31     28454.0
# 2018-01-31     26161.0
# 2018-02-28     24055.0
# 2018-03-31     31932.0
# 2018-04-30     35388.0
# 2018-05-31     16511.0
# 2018-06-30     29703.0
# 2018-07-31     41086.0

# %% [markdown]
# ### Step 13.

# %%
import seaborn as sns
#sns.regplot(x="talking_about_count", y="checkins", data=checkin_aggMonth);
sns.jointplot(x="sum_pre", y="checkins", data=checkin_month, kind="reg");

# %% [markdown]
# ### Step 14. Consider the total number of collisions each year from 2013-2018. Is there an apparent trend? Fit a linear regression for the number of collisions per year and report its slope.

# %%
#x, y = pd.Series(checkin_month, name="talking_about_count"), pd.Series(checkin_month, name="checkins")
#ax = sns.regplot(x=x, y=y, marker="+")
x= pd.Series(checkin_month.iloc[1:-1,0], name="talking_about_count")
y = pd.Series(checkin_month.iloc[2:,1], name="checkins")
ax = sns.regplot(x=x, y=y, marker="+")

# %% [markdown]
# ### Step 15.

# %%
sns.jointplot(x=x, y=y, kind="reg");

# %% [markdown]
# ### Step 16.

# %%
from sklearn.linear_model import LinearRegression
linear=checkin_month.reset_index()
'''
model = LinearRegression().fit(linear['time'], linear[['checkins']])
m = model.coef_[0]
b = model.intercept_
#equation of the line
print 'y = ', round(m[0],2), 'x + ', round(b[0],2)
'''
# Out:
# "\nmodel = LinearRegression().fit(linear['time'], linear[['checkins']])\nm = model.coef_[0]\nb = model.intercept_\n#equation of the line\nprint 'y = ', round(m[0],2), 'x + ', round(b[0],2)\n"

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
linear  = linear[4:]

# %%
import statsmodels.api as sm
model = sm.OLS(endog=linear['checkins'], exog=linear[['pre_talk','pre_talk_2']])
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               checkins   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     74.85
# Date:                Sun, 05 May 2019   Prob (F-statistic):           8.56e-13
# Time:                        13:18:46   Log-Likelihood:                -385.02
# No. Observations:                  34   AIC:                             774.0
# Df Residuals:                      32   BIC:                             777.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pre_talk       0.0494      0.211      0.234      0.817      -0.381       0.480
# pre_talk_2     1.4627      0.214      6.849      0.000       1.028       1.898
# ==============================================================================
# Omnibus:                        7.843   Durbin-Watson:                   1.390
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                6.392
# Skew:                           0.872   Prob(JB):                       0.0409
# Kurtosis:                       4.213   Cond. No.                         3.16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
model = sm.OLS(endog=linear['checkins'], exog=linear[['pre_talk_2']])
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               checkins   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     154.1
# Date:                Sun, 05 May 2019   Prob (F-statistic):           5.58e-14
# Time:                        13:19:07   Log-Likelihood:                -385.05
# No. Observations:                  34   AIC:                             772.1
# Df Residuals:                      33   BIC:                             773.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pre_talk_2     1.5035      0.121     12.412      0.000       1.257       1.750
# ==============================================================================
# Omnibus:                        7.851   Durbin-Watson:                   1.374
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                6.399
# Skew:                           0.873   Prob(JB):                       0.0408
# Kurtosis:                       4.211   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
model = sm.OLS(endog=linear['checkins'], exog=linear[['pre_talk_3','pre_talk_2']])
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               checkins   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     79.50
# Date:                Sun, 05 May 2019   Prob (F-statistic):           6.25e-13
# Time:                        13:21:39   Log-Likelihood:                -371.96
# No. Observations:                  33   AIC:                             747.9
# Df Residuals:                      31   BIC:                             750.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pre_talk_3     0.0779      0.204      0.382      0.705      -0.338       0.493
# pre_talk_2     1.4163      0.201      7.051      0.000       1.007       1.826
# ==============================================================================
# Omnibus:                       11.567   Durbin-Watson:                   1.448
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.030
# Skew:                           1.027   Prob(JB):                      0.00244
# Kurtosis:                       5.129   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
# Out:
# ('Parameters: ', pre_talk_3    0.077894
# pre_talk_2    1.416329
# dtype: float64)
# ('R2: ', 0.8368384768128865)

# %%
import seaborn as sns
#sns.regplot(x="talking_about_count", y="checkins", data=checkin_aggMonth);
sns.jointplot(x="pre_talk_2", y="checkins", data=linear, kind="reg");
